# %% [markdown]
# # Implementing an autoregressive Seq2Seq model using LSTM architecture
#
# ### About this notebook
#
# This notebook was created as a deliverable for the group project under 50.039 Deep Learning course at the Singapore University of Technology and Design.
#
# **Author:** Group 17 - Cohort 01

# %% [markdown]
# ## Define device for Torch - preferred CUDA for accelerated computation

# %%
# Matplotlib
import torch

# Define device for torch
use_cuda = True
print("CUDA is available:", torch.cuda.is_available())
device = torch.device("cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")
# Out:
# CUDA is available: True

# %% [markdown]
# ## Import train and test dataset

# %% [markdown]
# ### Define load dataset function

# %%
import pandas as pd

def load_dataset(train_path, test_path):
    # Load and drop date column
    train_df = pd.read_csv(train_path, parse_dates=['date']).drop(columns=['date'])
    test_df = pd.read_csv(test_path, parse_dates=['date']).drop(columns=['date'])

    # Normalize using training statistics
    stats = train_df.describe().transpose()

    def normalize(df):
        return (df - stats["mean"]) / stats["std"]

    train_norm = normalize(train_df)
    test_norm = normalize(test_df)

    return train_norm, test_norm, stats

# %% [markdown]
# ### Load train and test dataset

# %%
# Load dataset from file
train_file_path = '../dataset/train/DailyDelhiClimateTrain.csv'
test_file_path = '../dataset/test/DailyDelhiClimateTest.csv'
train_data, test_data, stats = load_dataset(train_file_path, test_file_path)

# %%
train_data[:5]
# Out:
#    meantemp  humidity  wind_speed  meanpressure
# 0 -2.108778  1.414955   -1.491189      0.025313
# 1 -2.462611  1.862191   -0.837909      0.037149
# 2 -2.494366  1.564034   -0.475464      0.041958
# 3 -2.290231  0.629806   -1.220816      0.033635
# 4 -2.653137  1.554095   -0.680070      0.029936

# %%
# number of samples in train dataset
len(train_data)
# Out:
# 1462

# %% [markdown]
# ## Define Pytorch Dataset and Dataloader objects

# %%
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader

# %% [markdown]
# ### Dataset object

# %%
class CustomDataset(Dataset):
    def __init__(self, dataframe, n_inputs, n_outputs):
        self.dataframe = dataframe
        self.n_inputs = n_inputs
        self.n_outputs = n_outputs
        self.inputs = []
        self.outputs = []
        self.define_samples()

    def define_samples(self):
        data_array = self.dataframe.values
        for i in range(len(data_array) - self.n_inputs - self.n_outputs):
            input_seq = data_array[i:i+self.n_inputs, :]         # Sequence length of 30, incl all features
            output_seq = data_array[i+self.n_inputs:i+self.n_inputs+self.n_outputs, :]  # Sequence length of 7, incl all features
            self.inputs.append(input_seq)
            self.outputs.append(output_seq)

    def __len__(self):
        return len(self.inputs)

    def __getitem__(self, idx):
        x = torch.tensor(self.inputs[idx], dtype=torch.float32)  # Shape: (n_inputs, 4)
        y = torch.tensor(self.outputs[idx], dtype=torch.float32) # Shape: (n_outputs,)
        return x, y

# %%
n_inputs = 30
n_outputs = 7

train_dataset = CustomDataset(train_data, n_inputs, n_outputs)
test_dataset = CustomDataset(test_data, n_inputs, n_outputs)

# %%
train_dataset[0]
# Out:
# (tensor([[-2.1088e+00,  1.4150e+00, -1.4912e+00,  2.5313e-02],
#          [-2.4626e+00,  1.8622e+00, -8.3791e-01,  3.7149e-02],
#          [-2.4944e+00,  1.5640e+00, -4.7546e-01,  4.1958e-02],
#          [-2.2902e+00,  6.2981e-01, -1.2208e+00,  3.3635e-02],
#          [-2.6531e+00,  1.5541e+00, -6.8007e-01,  2.9936e-02],
#          [-2.5170e+00,  1.3136e+00, -1.1667e+00,  3.8259e-02],
#          [-2.5170e+00,  1.0631e+00, -1.1009e-01,  4.9356e-02],
#          [-2.2643e+00,  1.7547e-01,  7.4677e-02,  4.2222e-02],
#          [-1.5644e+00, -5.6779e-01,  1.2491e+00,  3.2710e-02],
#          [-1.9727e+00,  7.3245e-02,  1.3105e-01,  2.5313e-02],
#          [-1.3311e+00, -5.6566e-01,  8.2629e-01,  2.7955e-02],
#          [-1.5644e+00,  7.8882e-01,  1.4088e+00,  2.4784e-02],
#          [-1.3149e+00,  8.5839e-01, -4.7546e-01,  1.2366e-02],
#          [-1.7232e+00,  1.6336e+00, -1.3560e+00,  2.2538e-02],
#          [-1.4672e+00,  6.6104e-01, -1.3753e+00,  2.6369e-02],
#          [-1.5871e+00,  1.5442e+00, -1.4912e+00,  3.0861e-02],
#          [-1.2242e+00,  1.1963e+00, -3.4028e-01,  2.6237e-02],
#          [-1.5871e+00,  1.8721e+00,  4.7084e-01,  1.8839e-02],
#          [-1.7686e+00,  9.4784e-01, -2.0144e-01,  5.8603e-02],
#          [-1.9338e+00,  8.6549e-01,  3.6593e-01,  5.0941e-02],
#          [-1.9455e+00,  9.6772e-01, -1.0045e+00,  5.4904e-02],
#          [-2.1768e+00,  1.1267e+00, -8.1526e-01,  5.9343e-02],
#          [-1.5644e+00, -3.6079e-02, -6.1065e-01,  5.2130e-02],
#          [-1.5871e+00, -6.2634e-03, -1.3932e-01,  5.2130e-02],
#          [-1.8026e+00,  3.7140e-01, -2.7451e-01,  5.3517e-02],
#          [-1.7459e+00,  2.0245e-01, -4.8420e-04,  4.7506e-02],
#          [-1.7200e+00,  2.8622e-01, -2.7294e-01,  3.9051e-02],
#          [-1.4510e+00, -2.8454e-01, -6.8007e-01,  3.7334e-02],
#          [-1.5474e+00,  2.8196e-01, -7.8146e-01,  3.0630e-02],
#          [-1.4672e+00,  5.7585e-01, -1.2594e+00,  3.7466e-02]]),
#  tensor([[-1.2650,  0.2879, -0.8423,  0.0405],
#          [-1.2922,  0.7292, -1.0045,  0.0272],
#          [-1.2534,  1.0018, -1.1999,  0.0335],
#          [-1.0201,  0.2862, -1.0841,  0.0232],
#          [-1.0978,  0.8059,  0.9453,  0.0192],
#          [-1.2072,  1.8846,  0.6407,  0.0292],
#          [-1.2015,  0.6298,  0.4014,  0.0420]]))

# %% [markdown]
# ### Dataloader Object

# %%
# Define batch size
batch_size = 128

# Random number generator (for reproducibility)
generator = torch.Generator()  # Defaults to CPU, which DataLoader expects

# Create DataLoader
train_dataloader = DataLoader(
    train_dataset,
    batch_size=batch_size,
    shuffle=True,
    generator=generator
)

test_dataloader = DataLoader(
    test_dataset,
    batch_size=batch_size,
    shuffle=False,  # Important: don't shuffle test data
    generator=generator
)

# %%
# Visualize a sample
sample = next(iter(train_dataloader))
input_sample, output_sample = sample
print("Input shape:", input_sample.shape)   
print("Output shape:", output_sample.shape)
# Out:
# Input shape: torch.Size([128, 30, 4])
# Output shape: torch.Size([128, 7, 4])

# %%
len(train_dataloader)
# Out:
# 12

# %% [markdown]
# ## Define Model Architecture

# %% [markdown]
# ### Our encoder model
#
# The EncoderLSTM below processes input sequences through an LSTM. It is designed to capture the temporal dependencies in the data.
# Only the final hidden states are returned, encapsulating the learned representation of the entire sequence. This encoder can be used in sequence-to-sequence models, where its hidden state initializes the decoder to generate outputs based on the input sequence.
#
# It uses several layers of LSTM and possibly dropout.

# %% [markdown]
# ##### Define Encoder class

# %%
# Numpy
import numpy as np
# Torch
import torch
import torch.nn as nn

# %%
class EncoderLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers = 1, dropout = 0.0):
        super(EncoderLSTM, self).__init__() 
        
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        
        self.lstm = nn.LSTM(input_size, hidden_size, 
                            num_layers = num_layers, 
                            dropout = dropout if num_layers > 1 else 0.0, 
                            batch_first = False)

    def forward(self, input_seq):
        # For this encoder, we ignore the outputs if we only need the final hidden state(s)
        outputs, hidden = self.lstm(input_seq)
        return hidden

# %%
# Defining our EncoderRNN model
hidden_size = 64
encoder_model = EncoderLSTM(4, hidden_size)
print(encoder_model)
# Out:
# EncoderLSTM(
#   (lstm): LSTM(4, 64)
# )

# %% [markdown]
# #### Testing Encoder model

# %%
# Grab one batch from the train dataloader
inputs, _ = next(iter(train_dataloader))  # inputs shape: (batch_size, seq_len, input_size)

# Rearrange for GRU: (seq_len, batch_size, input_size)
inputs = inputs.permute(1, 0, 2)  # (seq_len, batch_size, input_size)

print("Input shape to encoder:", inputs.shape)  # Should be (seq_len, batch_size, 4)

# Pass through encoder
encoder_out = encoder_model(inputs)

print("Encoder output (last hidden state) shape:", encoder_out[0].shape)  # (1, batch_size, hidden_size)
print("Sample vector:", encoder_out[0])
# Out:
# Input shape to encoder: torch.Size([30, 128, 4])
# Encoder output (last hidden state) shape: torch.Size([1, 128, 64])
# Sample vector: tensor([[[ 0.0605,  0.1055, -0.0413,  ..., -0.0300,  0.0267,  0.0915],
#          [ 0.0332, -0.1320,  0.0466,  ..., -0.1056, -0.0961, -0.0024],
#          [ 0.0384,  0.0612,  0.0061,  ...,  0.0198, -0.0192,  0.0628],
#          ...,
#          [ 0.0567, -0.0465,  0.0312,  ..., -0.0639, -0.0949, -0.0043],
#          [ 0.0772,  0.0769, -0.0160,  ..., -0.0533, -0.0346,  0.0293],
#          [ 0.0432, -0.0029,  0.0277,  ...,  0.0025, -0.0698,  0.0184]]],
#        grad_fn=<StackBackward0>)

# %% [markdown]
# ### Our decoder model
#
# The DecoderLSTM class is a PyTorch module designed to act as the decoder in a sequence-to-sequence architecture. It processes input sequences using an LSTM and then maps the LSTM outputs to the desired output space with a linear layer. It returns both the predicted output and the updated hidden state, making it suitable for sequential decoding in sequence-to-sequence tasks.

# %% [markdown]
# #### Define Decoder class

# %%
class DecoderLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers = 1, dropout = 0.0):
        super(DecoderLSTM, self).__init__()
        
        self.hidden_size = hidden_size
        
        self.num_layers = num_layers
        
        self.output_size=output_size
        
        self.lstm = nn.LSTM(input_size, hidden_size, 
                            num_layers = num_layers, 
                            dropout = dropout if num_layers > 1 else 0.0, 
                            batch_first = False)
        
        self.linear = nn.Linear(hidden_size, self.output_size)

    def forward(self, input_seq, hidden,output_length,target=None):
        outputs = []
        decoder_input = input_seq 

        for i in range(output_length):
            # One step forward through LSTM
            decoder_output, hidden = self.lstm(decoder_input, hidden)
            
            decoder_output = self.linear(decoder_output)  
            outputs.append(decoder_output)

            if target is not None:
                decoder_input = target[i].unsqueeze(0)
            else:
                decoder_input = decoder_output.detach() 

        return torch.cat(outputs, dim=0)  # shape: (output_length, batch_size, 1)

# %%
# Defining our DecoderRNN model
decoder_model = DecoderLSTM(input_size=4,hidden_size = hidden_size, output_size= 4)
print(decoder_model)
# Out:
# DecoderLSTM(
#   (lstm): LSTM(4, 64)
#   (linear): Linear(in_features=64, out_features=4, bias=True)
# )

# %% [markdown]
# #### Testing Decoder model

# %%
# Testing our DecoderRNN model

# Get a batch from dataloader
inputs, _ = next(iter(train_dataloader))  # inputs: (batch_size, seq_length, input_size)

# Permute for encoder: (seq_length, batch_size, input_size)
encoder_input = inputs.permute(1, 0, 2)

# Pass through encoder
encoder_hidden = encoder_model(encoder_input)  # shape: (1, batch_size, hidden_size)

# Initial decoder input: zeros, shape (1, batch_size, 1)
decoder_input = torch.zeros(1, inputs.size(0), 4).to(encoder_input.device)

# Run decoder
decoder_output = decoder_model(decoder_input, encoder_hidden, n_outputs)

# Output shape: (T_out, B, 1)
print("Decoder output shape:", decoder_output.shape)
# Out:
# Decoder output shape: torch.Size([7, 128, 4])

# %% [markdown]
# ### Our Seq2Seq model
#
# Assembling our encoder and decoder classes from earlier, the Seq2Seq class implements a sequence-to-sequence model using an encoder-decoder architecture. The encoder processes the input sequence to produce a final hidden state, which is then used as the starting point for the memory vector of the decoder. The decoder is then responsible for generating the output sequence.

# %% [markdown]
# #### Define Seq2Seq class

# %%
class Seq2SeqLSTM(nn.Module):
    def __init__(self, hidden_size, input_size, output_size,output_length,num_layers=1):
        super(Seq2SeqLSTM, self).__init__()
        
        self.output_length = output_length
        
        self.encoder = EncoderLSTM(input_size=input_size, 
                                   hidden_size=hidden_size,
                                   num_layers=num_layers)  # 4 features
        
        self.decoder = DecoderLSTM(input_size=input_size,
                                   hidden_size=hidden_size,
                                   output_size=output_size,
                                   num_layers=num_layers)  # 4 features

    def forward(self, inputs, outputs=None):
        hidden = self.encoder(inputs)  # returns (1, batch_size, hidden_size)

        # Initial decoder input: zeros (1, batch_size, 4)
        decoder_input = torch.zeros(1, inputs.shape[1], self.decoder.output_size).to(inputs.device)

        # Pass to decoder
        output = self.decoder(decoder_input, hidden, self.output_length, outputs)
        
        return output  # shape: (output_length, batch_size, 1)

# %%
# Defining our Seq2Seq model
seq2seq_model = Seq2SeqLSTM(input_size=4,output_size=4,hidden_size = hidden_size, \
                        output_length=n_outputs)
print(seq2seq_model)
# Out:
# Seq2SeqLSTM(
#   (encoder): EncoderLSTM(
#     (lstm): LSTM(4, 64)
#   )
#   (decoder): DecoderLSTM(
#     (lstm): LSTM(4, 64)
#     (linear): Linear(in_features=64, out_features=4, bias=True)
#   )
# )

# %% [markdown]
# #### Testing seq2seq model

# %%
# Instantiate model
seq2seq_model = Seq2SeqLSTM(input_size=4,output_size=4,hidden_size = hidden_size, \
                        output_length=n_outputs).to(device)

# Get a batch from the dataloader
inputs, outputs = next(iter(train_dataloader))  # shapes: (B, T_in, 4), (B, T_out)

inputs = inputs.to(device)
outputs = outputs.to(device)

# Permute to (seq_length, batch_size, input_size)
inputs = inputs.permute(1, 0, 2)
outputs = outputs.permute(1, 0, 2)

print("Input shape:", inputs.shape)   # (input_seq_len, batch_size, 4)
print("Target shape:", outputs.shape) # (output_seq_len, batch_size, 1)

# Forward pass
seq2seq_out = seq2seq_model(inputs, outputs)

print("Output shape:", seq2seq_out.shape)  # (output_seq_len, batch_size, 1)
# Out:
# Input shape: torch.Size([30, 128, 4])
# Target shape: torch.Size([7, 128, 4])
# Output shape: torch.Size([7, 128, 4])

# %% [markdown]
# ## Model training

# %% [markdown]
# ### Define function for training

# %%
loss_storage=[]

def train_model(dataloader, model, num_epochs, learning_rate, device):
    # Set model to training mode
    model.train()
    
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    for epoch in range(num_epochs):
        total_loss = 0

        for inputs, targets in dataloader:
            # Move to device
            inputs = inputs.to(device)
            targets = targets.to(device)

            # Reshape to (seq_len, batch_size, input_size)
            inputs = inputs.permute(1, 0, 2)  # (T_in, B, 4)
            targets = targets.permute(1, 0, 2)  # (T_out, B, 4)

            # Zero gradients
            optimizer.zero_grad()

            # Forward pass with teacher forcing
            predictions = model(inputs, targets)

            # Compute loss
            loss = criterion(predictions, targets)
            total_loss += loss.item()

            # Backward pass and optimize
            loss.backward()
            optimizer.step()

      
        avg_loss = total_loss / len(dataloader)
        
        loss_storage.append(avg_loss)
        
        print(f"Epoch {epoch + 1}/{num_epochs}, Average Loss: {avg_loss:.4f}")

# %% [markdown]
# ### Instantiate a model from Seq2Seq class

# %%
# Hyperparameters
input_size = 4 
hidden_size = 100
output_size = 4
learning_rate = 0.001
num_epochs = 300
num_layers = 3
dropout_rate = 0.1

# Instantiate model
seq2seq_model = Seq2SeqLSTM(input_size=input_size,
                            output_size=output_size,
                            hidden_size = hidden_size, \
                            output_length=n_outputs).to(device)

# %% [markdown]
# ### Train model

# %%
# Train the model
train_model(dataloader=train_dataloader,
            model=seq2seq_model,
            num_epochs=num_epochs,
            learning_rate=learning_rate,device=device 
            )
# Out:
# Epoch 1/300, Average Loss: 0.9068
# Epoch 2/300, Average Loss: 0.7556
# Epoch 3/300, Average Loss: 0.6202
# Epoch 4/300, Average Loss: 0.5814
# Epoch 5/300, Average Loss: 0.5497
# Epoch 6/300, Average Loss: 0.5459
# Epoch 7/300, Average Loss: 0.7426
# Epoch 8/300, Average Loss: 0.5250
# Epoch 9/300, Average Loss: 0.7276
# Epoch 10/300, Average Loss: 0.5164
# Epoch 11/300, Average Loss: 0.5121
# Epoch 12/300, Average Loss: 0.5144
# Epoch 13/300, Average Loss: 0.5167
# Epoch 14/300, Average Loss: 0.4971
# Epoch 15/300, Average Loss: 0.5044
# Epoch 16/300, Average Loss: 0.5010
# Epoch 17/300, Average Loss: 0.7016
# Epoch 18/300, Average Loss: 0.4999
# Epoch 19/300, Average Loss: 0.4876
# Epoch 20/300, Average Loss: 0.4857
# Epoch 21/300, Average Loss: 0.6948
# Epoch 22/300, Average Loss: 0.4832
# Epoch 23/300, Average Loss: 0.5042
# Epoch 24/300, Average Loss: 0.7009
# Epoch 25/300, Average Loss: 0.4812
# Epoch 26/300, Average Loss: 0.6748
# Epoch 27/300, Average Loss: 0.5059
# Epoch 28/300, Average Loss: 0.4833
# Epoch 29/300, Average Loss: 0.4802
# Epoch 30/300, Average Loss: 0.4785
# Epoch 31/300, Average Loss: 0.4754
# Epoch 32/300, Average Loss: 0.4763
# Epoch 33/300, Average Loss: 0.4583
# Epoch 34/300, Average Loss: 0.4751
# Epoch 35/300, Average Loss: 0.4609
# Epoch 36/300, Average Loss: 0.4484
# Epoch 37/300, Average Loss: 0.4467
# Epoch 38/300, Average Loss: 0.4391
# Epoch 39/300, Average Loss: 0.4333
# Epoch 40/300, Average Loss: 0.4757
# Epoch 41/300, Average Loss: 0.4458
# Epoch 42/300, Average Loss: 0.4347
# Epoch 43/300, Average Loss: 0.4214
# Epoch 44/300, Average Loss: 0.4505
# Epoch 45/300, Average Loss: 0.4093
# Epoch 46/300, Average Loss: 0.4008
# Epoch 47/300, Average Loss: 0.4003
# Epoch 48/300, Average Loss: 0.3881
# Epoch 49/300, Average Loss: 0.3772
# Epoch 50/300, Average Loss: 0.3663
# Epoch 51/300, Average Loss: 0.3657
# Epoch 52/300, Average Loss: 0.3671
# Epoch 53/300, Average Loss: 0.3603
# Epoch 54/300, Average Loss: 0.3659
# Epoch 55/300, Average Loss: 0.3582
# Epoch 56/300, Average Loss: 0.3701
# Epoch 57/300, Average Loss: 0.3566
# Epoch 58/300, Average Loss: 0.3482
# Epoch 59/300, Average Loss: 0.3360
# Epoch 60/300, Average Loss: 0.3542
# Epoch 61/300, Average Loss: 0.3300
# Epoch 62/300, Average Loss: 0.3165
# Epoch 63/300, Average Loss: 0.3160
# Epoch 64/300, Average Loss: 0.3153
# Epoch 65/300, Average Loss: 0.3079
# Epoch 66/300, Average Loss: 0.3129
# Epoch 67/300, Average Loss: 0.3063
# Epoch 68/300, Average Loss: 0.2938
# Epoch 69/300, Average Loss: 0.2920
# Epoch 70/300, Average Loss: 0.2907
# Epoch 71/300, Average Loss: 0.2856
# Epoch 72/300, Average Loss: 0.2902
# Epoch 73/300, Average Loss: 0.3285
# Epoch 74/300, Average Loss: 0.2837
# Epoch 75/300, Average Loss: 0.3003
# Epoch 76/300, Average Loss: 0.3647
# Epoch 77/300, Average Loss: 0.2856
# Epoch 78/300, Average Loss: 0.3107
# Epoch 79/300, Average Loss: 0.2628
# Epoch 80/300, Average Loss: 0.2723
# Epoch 81/300, Average Loss: 0.2993
# Epoch 82/300, Average Loss: 0.2861
# Epoch 83/300, Average Loss: 0.2517
# Epoch 84/300, Average Loss: 0.2503
# Epoch 85/300, Average Loss: 0.2479
# Epoch 86/300, Average Loss: 0.2477
# Epoch 87/300, Average Loss: 0.2357
# Epoch 88/300, Average Loss: 0.2432
# Epoch 89/300, Average Loss: 0.2312
# Epoch 90/300, Average Loss: 0.2330
# Epoch 91/300, Average Loss: 0.2305
# Epoch 92/300, Average Loss: 0.2282
# Epoch 93/300, Average Loss: 0.2393
# Epoch 94/300, Average Loss: 0.2186
# Epoch 95/300, Average Loss: 0.2166
# Epoch 96/300, Average Loss: 0.2177
# Epoch 97/300, Average Loss: 0.2304
# Epoch 98/300, Average Loss: 0.2134
# Epoch 99/300, Average Loss: 0.2106
# Epoch 100/300, Average Loss: 0.2113
# Epoch 101/300, Average Loss: 0.2095
# Epoch 102/300, Average Loss: 0.2029
# Epoch 103/300, Average Loss: 0.2116
# Epoch 104/300, Average Loss: 0.1986
# Epoch 105/300, Average Loss: 0.1991
# Epoch 106/300, Average Loss: 0.1968
# Epoch 107/300, Average Loss: 0.1952
# Epoch 108/300, Average Loss: 0.1979
# Epoch 109/300, Average Loss: 0.1940
# Epoch 110/300, Average Loss: 0.1903
# Epoch 111/300, Average Loss: 0.1906
# Epoch 112/300, Average Loss: 0.1890
# Epoch 113/300, Average Loss: 0.1910
# Epoch 114/300, Average Loss: 0.1837
# Epoch 115/300, Average Loss: 0.1873
# Epoch 116/300, Average Loss: 0.1863
# Epoch 117/300, Average Loss: 0.1824
# Epoch 118/300, Average Loss: 0.1806
# Epoch 119/300, Average Loss: 0.1817
# Epoch 120/300, Average Loss: 0.2044
# Epoch 121/300, Average Loss: 0.1966
# Epoch 122/300, Average Loss: 0.1867
# Epoch 123/300, Average Loss: 0.1799
# Epoch 124/300, Average Loss: 0.1799
# Epoch 125/300, Average Loss: 0.1705
# Epoch 126/300, Average Loss: 0.1713
# Epoch 127/300, Average Loss: 0.1846
# Epoch 128/300, Average Loss: 0.1753
# Epoch 129/300, Average Loss: 0.1716
# Epoch 130/300, Average Loss: 0.1714
# Epoch 131/300, Average Loss: 0.1621
# Epoch 132/300, Average Loss: 0.1622
# Epoch 133/300, Average Loss: 0.1642
# Epoch 134/300, Average Loss: 0.1573
# Epoch 135/300, Average Loss: 0.1623
# Epoch 136/300, Average Loss: 0.1745
# Epoch 137/300, Average Loss: 0.1868
# Epoch 138/300, Average Loss: 0.1672
# Epoch 139/300, Average Loss: 0.1628
# Epoch 140/300, Average Loss: 0.1598
# Epoch 141/300, Average Loss: 0.1636
# Epoch 142/300, Average Loss: 0.1581
# Epoch 143/300, Average Loss: 0.1536
# Epoch 144/300, Average Loss: 0.1523
# Epoch 145/300, Average Loss: 0.1468
# Epoch 146/300, Average Loss: 0.1476
# Epoch 147/300, Average Loss: 0.1489
# Epoch 148/300, Average Loss: 0.1524
# Epoch 149/300, Average Loss: 0.1518
# Epoch 150/300, Average Loss: 0.1492
# Epoch 151/300, Average Loss: 0.1472
# Epoch 152/300, Average Loss: 0.1456
# Epoch 153/300, Average Loss: 0.1387
# Epoch 154/300, Average Loss: 0.1378
# Epoch 155/300, Average Loss: 0.1430
# Epoch 156/300, Average Loss: 0.1400
# Epoch 157/300, Average Loss: 0.1391
# Epoch 158/300, Average Loss: 0.1376
# Epoch 159/300, Average Loss: 0.1376
# Epoch 160/300, Average Loss: 0.1350
# Epoch 161/300, Average Loss: 0.1377
# Epoch 162/300, Average Loss: 0.1360
# Epoch 163/300, Average Loss: 0.1350
# Epoch 164/300, Average Loss: 0.1302
# Epoch 165/300, Average Loss: 0.1293
# Epoch 166/300, Average Loss: 0.1353
# Epoch 167/300, Average Loss: 0.1393
# Epoch 168/300, Average Loss: 0.1336
# Epoch 169/300, Average Loss: 0.1307
# Epoch 170/300, Average Loss: 0.1308
# Epoch 171/300, Average Loss: 0.1313
# Epoch 172/300, Average Loss: 0.1354
# Epoch 173/300, Average Loss: 0.1279
# Epoch 174/300, Average Loss: 0.1263
# Epoch 175/300, Average Loss: 0.1262
# Epoch 176/300, Average Loss: 0.1238
# Epoch 177/300, Average Loss: 0.1181
# Epoch 178/300, Average Loss: 0.1194
# Epoch 179/300, Average Loss: 0.1187
# Epoch 180/300, Average Loss: 0.1222
# Epoch 181/300, Average Loss: 0.1167
# Epoch 182/300, Average Loss: 0.1170
# Epoch 183/300, Average Loss: 0.1211
# Epoch 184/300, Average Loss: 0.1224
# Epoch 185/300, Average Loss: 0.1162
# Epoch 186/300, Average Loss: 0.1126
# Epoch 187/300, Average Loss: 0.1139
# Epoch 188/300, Average Loss: 0.1168
# Epoch 189/300, Average Loss: 0.1144
# Epoch 190/300, Average Loss: 0.1182
# Epoch 191/300, Average Loss: 0.1163
# Epoch 192/300, Average Loss: 0.1117
# Epoch 193/300, Average Loss: 0.1089
# Epoch 194/300, Average Loss: 0.1066
# Epoch 195/300, Average Loss: 0.1062
# Epoch 196/300, Average Loss: 0.1076
# Epoch 197/300, Average Loss: 0.1085
# Epoch 198/300, Average Loss: 0.1064
# Epoch 199/300, Average Loss: 0.1059
# Epoch 200/300, Average Loss: 0.1038
# Epoch 201/300, Average Loss: 0.1036
# Epoch 202/300, Average Loss: 0.1066
# Epoch 203/300, Average Loss: 0.1130
# Epoch 204/300, Average Loss: 0.1120
# Epoch 205/300, Average Loss: 0.1082
# Epoch 206/300, Average Loss: 0.1040
# Epoch 207/300, Average Loss: 0.1004
# Epoch 208/300, Average Loss: 0.1012
# Epoch 209/300, Average Loss: 0.1007
# Epoch 210/300, Average Loss: 0.0969
# Epoch 211/300, Average Loss: 0.0945
# Epoch 212/300, Average Loss: 0.0971
# Epoch 213/300, Average Loss: 0.0986
# Epoch 214/300, Average Loss: 0.1004
# Epoch 215/300, Average Loss: 0.0999
# Epoch 216/300, Average Loss: 0.1033
# Epoch 217/300, Average Loss: 0.1029
# Epoch 218/300, Average Loss: 0.0987
# Epoch 219/300, Average Loss: 0.1014
# Epoch 220/300, Average Loss: 0.1012
# Epoch 221/300, Average Loss: 0.0932
# Epoch 222/300, Average Loss: 0.0901
# Epoch 223/300, Average Loss: 0.0891
# Epoch 224/300, Average Loss: 0.0900
# Epoch 225/300, Average Loss: 0.0906
# Epoch 226/300, Average Loss: 0.0909
# Epoch 227/300, Average Loss: 0.0912
# Epoch 228/300, Average Loss: 0.0890
# Epoch 229/300, Average Loss: 0.0881
# Epoch 230/300, Average Loss: 0.0865
# Epoch 231/300, Average Loss: 0.0871
# Epoch 232/300, Average Loss: 0.0847
# Epoch 233/300, Average Loss: 0.0860
# Epoch 234/300, Average Loss: 0.0842
# Epoch 235/300, Average Loss: 0.0827
# Epoch 236/300, Average Loss: 0.0825
# Epoch 237/300, Average Loss: 0.0818
# Epoch 238/300, Average Loss: 0.0812
# Epoch 239/300, Average Loss: 0.0809
# Epoch 240/300, Average Loss: 0.0801
# Epoch 241/300, Average Loss: 0.0834
# Epoch 242/300, Average Loss: 0.0817
# Epoch 243/300, Average Loss: 0.0836
# Epoch 244/300, Average Loss: 0.0859
# Epoch 245/300, Average Loss: 0.0861
# Epoch 246/300, Average Loss: 0.0852
# Epoch 247/300, Average Loss: 0.0827
# Epoch 248/300, Average Loss: 0.0819
# Epoch 249/300, Average Loss: 0.0794
# Epoch 250/300, Average Loss: 0.0806
# Epoch 251/300, Average Loss: 0.0778
# Epoch 252/300, Average Loss: 0.0769
# Epoch 253/300, Average Loss: 0.0749
# Epoch 254/300, Average Loss: 0.0754
# Epoch 255/300, Average Loss: 0.0769
# Epoch 256/300, Average Loss: 0.0779
# Epoch 257/300, Average Loss: 0.0757
# Epoch 258/300, Average Loss: 0.0757
# Epoch 259/300, Average Loss: 0.0751
# Epoch 260/300, Average Loss: 0.0733
# Epoch 261/300, Average Loss: 0.0714
# Epoch 262/300, Average Loss: 0.0717
# Epoch 263/300, Average Loss: 0.0696
# Epoch 264/300, Average Loss: 0.0713
# Epoch 265/300, Average Loss: 0.0722
# Epoch 266/300, Average Loss: 0.0734
# Epoch 267/300, Average Loss: 0.0708
# Epoch 268/300, Average Loss: 0.0686
# Epoch 269/300, Average Loss: 0.0677
# Epoch 270/300, Average Loss: 0.0686
# Epoch 271/300, Average Loss: 0.0692
# Epoch 272/300, Average Loss: 0.0675
# Epoch 273/300, Average Loss: 0.0693
# Epoch 274/300, Average Loss: 0.0699
# Epoch 275/300, Average Loss: 0.0691
# Epoch 276/300, Average Loss: 0.0669
# Epoch 277/300, Average Loss: 0.0654
# Epoch 278/300, Average Loss: 0.0661
# Epoch 279/300, Average Loss: 0.0645
# Epoch 280/300, Average Loss: 0.0679
# Epoch 281/300, Average Loss: 0.0704
# Epoch 282/300, Average Loss: 0.0716
# Epoch 283/300, Average Loss: 0.0742
# Epoch 284/300, Average Loss: 0.0781
# Epoch 285/300, Average Loss: 0.0829
# Epoch 286/300, Average Loss: 0.0768
# Epoch 287/300, Average Loss: 0.0729
# Epoch 288/300, Average Loss: 0.0690
# Epoch 289/300, Average Loss: 0.0667
# Epoch 290/300, Average Loss: 0.0657
# Epoch 291/300, Average Loss: 0.0635
# Epoch 292/300, Average Loss: 0.0633
# Epoch 293/300, Average Loss: 0.0615
# Epoch 294/300, Average Loss: 0.0608
# Epoch 295/300, Average Loss: 0.0625
# Epoch 296/300, Average Loss: 0.0620
# Epoch 297/300, Average Loss: 0.0607
# Epoch 298/300, Average Loss: 0.0616
# Epoch 299/300, Average Loss: 0.0596
# Epoch 300/300, Average Loss: 0.0590

# %% [markdown]
# ### Save the model parameter

# %%
# save model before eval
import torch
import os

model_name="seq2seq_non_autoregressive_LSTM"

# Path to save model
model_path = os.path.join("../models_weights_storage", f'{model_name}.pth')

# Save the model's state dict
torch.save(seq2seq_model.state_dict(), model_path)
print(f"Model saved to: {model_path}")
# Out:
# Model saved to: ../models_weights_storage/seq2seq_non_autoregressive_LSTM.pth

# %%
loss_storage
# Out:
# [0.9067913591861725,
#  0.7555991460879644,
#  0.620209239423275,
#  0.5814034268260002,
#  0.5497457745174567,
#  0.5458886499206225,
#  0.742620495458444,
#  0.5249607438842455,
#  0.7276233732700348,
#  0.5164174636205038,
#  0.5121224845449129,
#  0.5144056901335716,
#  0.5167118559281031,
#  0.49705810099840164,
#  0.5044186934828758,
#  0.5009976426760355,
#  0.7015803108612696,
#  0.49989236270387966,
#  0.48758288969596225,
#  0.485721405595541,
#  0.6948391360541185,
#  0.48315326993664104,
#  0.5042497689525286,
#  0.7008999735116959,
#  0.48122749105095863,
#  0.6747948142389456,
#  0.5058692743380865,
#  0.4833392985165119,
#  0.48016078025102615,
#  0.47849321241180104,
#  0.4754071819285552,
#  0.4763055642445882,
#  0.4582526112596194,
#  0.4750821714599927,
#  0.460911317418019,
#  0.44838422909379005,
#  0.446727463354667,
#  0.43909789249300957,
#  0.4332753283282121,
#  0.4756743734081586,
#  0.4457555003464222,
#  0.43467312057813007,
#  0.42136791969339055,
#  0.450496893376112,
#  0.4092575858036677,
#  0.40080486858884495,
#  0.40033574899037677,
#  0.3880719368656476,
#  0.3771920104821523,
#  0.3663007703920205,
#  0.36574139818549156,
#  0.3671188826362292,
#  0.36028406396508217,
#  0.3659299264351527,
#  0.35818706701199216,
#  0.3701334111392498,
#  0.3565767742693424,
#  0.34817057599623996,
#  0.3359756792585055,
#  0.35417235766847927,
#  0.33004873245954514,
#  0.3164702157179515,
#  0.3159548081457615,
#  0.3153240693112214,
#  0.3079013414680958,
#  0.3128928393125534,
#  0.30634502073129016,
#  0.2937677005926768,
#  0.29199353605508804,
#  0.29071864609917003,
#  0.28561197221279144,
#  0.2901674782236417,
#  0.3284948219855626,
#  0.28371578579147655,
#  0.3002861365675926,
#  0.36474952350060147,
#  0.2855735483268897,
#  0.31069931263724965,
#  0.2627592335144679,
#  0.2723392111559709,
#  0.2992579862475395,
#  0.28606364876031876,
#  0.2516776497165362,
#  0.2503216738502185,
#  0.2479324278732141,
#  0.24771741529305777,
#  0.23574357479810715,
#  0.24323767175277075,
#  0.23115979507565498,
#  0.2329662392536799,
#  0.2305192177494367,
#  0.22819343457619348,
#  0.23930832743644714,
#  0.2185987631479899,
#  0.21663755426804224,
#  0.2176674840350946,
#  0.23035789032777151,
#  0.21336879084507623,
#  0.2105577476322651,
#  0.21132093792160353,
#  0.20949866995215416,
#  0.2029037574927012,
#  0.21163690214355788,
#  0.19858880216876665,
#  0.19909112279613814,
#  0.19684988632798195,
#  0.1951986514031887,
#  0.19788448264201483,
#  0.19404855743050575,
#  0.19026370346546173,
#  0.19064719850818315,
#  0.18901565174261728,
#  0.19103388115763664,
#  0.18371364971001944,
#  0.18725537384549776,
#  0.18628169099489847,
#  0.18239621569712958,
#  0.1805911622941494,
#  0.18170490115880966,
#  0.20438098162412643,
#  0.19657218704620996,
#  0.18669166415929794,
#  0.17987439781427383,
#  0.1798885501921177,
#  0.1704528915385405,
#  0.17129932219783464,
#  0.18464263901114464,
#  0.17525961001714072,
#  0.17156294733285904,
#  0.17140612999598184,
#  0.162099314853549,
#  0.16221724698940912,
#  0.16422483449180922,
#  0.15729034692049026,
#  0.16230586419502893,
#  0.17446231842041016,
#  0.18675837914148966,
#  0.16720420370499292,
#  0.16283755376935005,
#  0.15983396644393602,
#  0.16357602179050446,
#  0.15813831860820451,
#  0.1536466802159945,
#  0.15232564260562262,
#  0.14675366381804147,
#  0.14761081462105116,
#  0.14885767549276352,
#  0.1523510329425335,
#  0.15179461489121118,
#  0.14919143666823706,
#  0.14723477388421694,
#  0.14558977509538332,
#  0.1386712727447351,
#  0.1378349450727304,
#  0.14295346289873123,
#  0.14002747337023416,
#  0.1390706915408373,
#  0.13758047173420587,
#  0.13758142292499542,
#  0.1350291408598423,
#  0.13774611925085387,
#  0.13596544849375883,
#  0.13503614316383997,
#  0.1301662257562081,
#  0.12930820882320404,
#  0.1352507726599773,
#  0.1393180452287197,
#  0.13357882760465145,
#  0.13068792968988419,
#  0.13079375214874744,
#  0.13125953699151674,
#  0.135359650477767,
#  0.1278625844667355,
#  0.12627757340669632,
#  0.1262428363164266,
#  0.12381453812122345,
#  0.11806988281508286,
#  0.11939187223712604,
#  0.11874297261238098,
#  0.12223067631324132,
#  0.11672937435408433,
#  0.11698428293069203,
#  0.1211130910863479,
#  0.12238862675925095,
#  0.11622423430283864,
#  0.11260188867648442,
#  0.11387156943480174,
#  0.11680070497095585,
#  0.11440038246413071,
#  0.11815958035488923,
#  0.11632845178246498,
#  0.11167993272344272,
#  0.10885268822312355,
#  0.10662551472584407,
#  0.1061602458357811,
#  0.10763395763933659,
#  0.10854789117972057,
#  0.1064142386118571,
#  0.10587867101033528,
#  0.10382821535070737,
#  0.10360713427265485,
#  0.10657025935749213,
#  0.1129633237918218,
#  0.1120337185760339,
#  0.10817574709653854,
#  0.10403804418941338,
#  0.10039417321483295,
#  0.10115377853314082,
#  0.10072874774535497,
#  0.09688124495248,
#  0.09450900616745155,
#  0.09713533520698547,
#  0.09856519351402919,
#  0.10038231872022152,
#  0.09988503530621529,
#  0.10328570567071438,
#  0.10286498504380386,
#  0.09874081735809644,
#  0.10138577843705814,
#  0.10119314988454182,
#  0.09322193389137585,
#  0.09008047108848889,
#  0.08914772296945254,
#  0.08995387392739455,
#  0.09062473538021247,
#  0.09094148750106494,
#  0.09122129529714584,
#  0.08904011982182662,
#  0.0881363283842802,
#  0.0865113257120053,
#  0.08708590393265088,
#  0.08467588449517886,
#  0.08595667965710163,
#  0.08422061987221241,
#  0.08268690916399161,
#  0.08248051007588704,
#  0.08180998203655084,
#  0.08119361288845539,
#  0.08094325537482898,
#  0.08008898297945659,
#  0.0833590676387151,
#  0.08172573149204254,
#  0.08357004448771477,
#  0.08586483324567477,
#  0.08608813770115376,
#  0.08520109082261722,
#  0.08272059603283803,
#  0.08193285452822845,
#  0.07944085883597533,
#  0.08064640996356805,
#  0.07783358668287595,
#  0.07688650923470657,
#  0.07486121729016304,
#  0.07544061293204625,
#  0.07690792841215928,
#  0.0779073399802049,
#  0.07572325815757115,
#  0.07569520423809688,
#  0.07507397917409737,
#  0.0732955156515042,
#  0.07144774061938126,
#  0.07169711217284203,
#  0.06962374163170655,
#  0.07125248139103253,
#  0.07218545985718568,
#  0.07344004201392333,
#  0.07075134788950284,
#  0.06858418757716815,
#  0.06772681480894487,
#  0.06859350204467773,
#  0.06918059537808101,
#  0.06748828416069348,
#  0.06927743305762608,
#  0.06991052192946275,
#  0.06914932591219743,
#  0.06686350641151269,
#  0.06540339005490144,
#  0.06605231141050656,
#  0.06446113872031371,
#  0.06792926167448361,
#  0.07037823057423036,
#  0.07160504410664241,
#  0.07416842877864838,
#  0.07814934353033702,
#  0.0828923862427473,
#  0.07675483636558056,
#  0.07286051474511623,
#  0.06895068256805341,
#  0.06673724390566349,
#  0.06574509292840958,
#  0.06347146133581798,
#  0.06333869167913993,
#  0.06145383541782697,
#  0.06078601100792488,
#  0.062467822494606175,
#  0.061966838936010994,
#  0.060742113118370376,
#  0.061557894572615623,
#  0.059561475490530334,
#  0.05900697410106659]

# %% [markdown]
# ## Plot loss curve during model training

# %% [markdown]
# ### Define a function to plot the loss curve

# %%
import matplotlib.pyplot as plt

def plot_loss_curve(loss_storage, tick_interval=10,save_path=None):
    plt.figure(figsize=(12, 6))
    
    epochs = list(range(1, len(loss_storage) + 1))
    
    # Plot the loss
    plt.plot(
        epochs,
        loss_storage,
        color='royalblue',
        marker='o',
        linestyle='-',
        linewidth=2,
        markersize=4,
        label='Training Loss'
    )

    # Title & labels
    plt.title("Training Loss Curve", fontsize=18, fontweight='bold')
    plt.xlabel("Epoch", fontsize=14)
    plt.ylabel("Loss", fontsize=14)

    # Set x-ticks with wider spacing
    plt.xticks(
        ticks=range(0, len(loss_storage) + 1, tick_interval),
        fontsize=12
    )
    plt.yticks(fontsize=12)

    # Grid, legend and layout
    plt.grid(True, linestyle='--', linewidth=0.5)
    plt.legend(fontsize=12)
    plt.tight_layout()
    
    if save_path:
        plt.savefig(save_path, dpi=300, bbox_inches='tight')
        print(f"Loss curve saved to: {save_path}")
        
    plt.show()

# %% [markdown]
# ### Plot the loss curve and save the image

# %%
save_path="../images_model_training_and_eval/seq2seq_non_autoregressive_LSTM_loss_training_curve.png"

plot_loss_curve(loss_storage,save_path=save_path)
# Out:
# Loss curve saved to: ../images_model_training_and_eval/seq2seq_non_autoregressive_LSTM_loss_training_curve.png

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# ### Define evaluation model function

# %%
def evaluate_model(model, dataloader, seed_value):
    model.eval()
    torch.manual_seed(seed_value)
    torch.cuda.manual_seed_all(seed_value)
    np.random.seed(seed_value)

    inputs, outputs = next(iter(dataloader))
    inputs = inputs.to(device)
    outputs = outputs.to(device)

    inputs_seq = inputs.permute(1, 0, 2)
    outputs_seq = outputs.permute(1, 0, 2)

    pred = model(inputs_seq)

    true_vals = outputs_seq.cpu().numpy()[:, 0, :]
    pred_vals = pred.detach().cpu().numpy()[:, 0, :]

    print("Ground truth:\n", true_vals.T)
    print("Prediction:\n", pred_vals.T)
    print("MAE:", np.mean(np.abs(true_vals - pred_vals)))

    feature_mae = np.mean(np.abs(true_vals - pred_vals), axis=(0, 1))
    print("Feature-wise MAE:", feature_mae)

# %%
seed_value=187

evaluate_model(seq2seq_model,test_dataloader,seed_value)
# Out:
# Ground truth:
#  [[-1.2752299  -1.3943083  -1.1437798  -1.3417282  -0.9247994  -0.93411076
#   -1.1712726 ]
#  [ 0.9080867   1.0646194   0.3442977   1.0381919   1.0034971   1.0053803
#    0.53042036]
#  [-0.47729036 -0.37316027 -0.82754606 -1.0846328   0.6615639   0.28450337
#    0.49154565]
#  [ 0.02438779  0.03548462  0.04330284  0.03674562  0.01828454  0.01723326
#    0.027162  ]]
# Prediction:
#  [[-1.1918772  -1.1021496  -1.0712345  -1.2421063  -1.3768655  -1.3667377
#   -1.4383093 ]
#  [ 0.47196785  0.42135504  0.09226443  0.41778734  0.5715406   0.48975363
#    0.71161485]
#  [-0.5816452  -0.4041743   0.7468791   0.64045846 -0.11517391  0.0661728
#   -0.09265078]
#  [-0.2895077   0.02437125  0.15907364  0.06668906 -0.00445218  0.06765167
#    0.13859196]]
# MAE: 0.3731952
# Feature-wise MAE: 0.3731952

# %% [markdown]
# #### Define function to plot prediction versus ground truth

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch

def visualize_some_predictions(model, dataloader, device, stats=None, indices=[2486, 2986]):
    feature_names = ['meantemp', 'humidity', 'wind_speed', 'meanpressure']
    colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']  # Custom colors for features

    plt.style.use('ggplot')  
    model.eval()

    num_features = len(feature_names)
    num_samples = len(indices)
    
    fig, axs = plt.subplots(num_samples, num_features, figsize=(5 * num_features, 4 * num_samples))

    for row, seed in enumerate(indices):
        g = torch.Generator()
        g.manual_seed(seed)

        data_iter = iter(torch.utils.data.DataLoader(
            dataloader.dataset, batch_size=32, shuffle=True, generator=g
        ))

        inputs, outputs = next(data_iter)
        inputs, outputs = inputs.to(device), outputs.to(device)

        inputs_seq = inputs.permute(1, 0, 2)      # (T_in, B, F)
        outputs_seq = outputs.permute(1, 0, 2)    # (T_out, B, F)
        preds = model(inputs_seq)                # (T_out, B, F)

        b = 0  # first sample in the batch

        x = inputs[b].detach().cpu().numpy()         # (T_in, F)
        y_true = outputs_seq[:, b, :].detach().cpu().numpy()  # (T_out, F)
        y_pred = preds[:, b, :].detach().cpu().numpy()        # (T_out, F)

        # Denormalize if stats provided
        if stats is not None:
            for i, name in enumerate(feature_names):
                mean = stats.loc[name, 'mean']
                std = stats.loc[name, 'std']
                x[:, i] = x[:, i] * std + mean
                y_true[:, i] = y_true[:, i] * std + mean
                y_pred[:, i] = y_pred[:, i] * std + mean

        # Time steps
        t1 = list(range(x.shape[0]))  # input timesteps
        t3 = [x.shape[0] + i + 1 for i in range(y_true.shape[0])]  # prediction timesteps

        mse = np.mean((y_true - y_pred) ** 2)

        for col in range(num_features):
            ax = axs[row, col] if num_samples > 1 else axs[col]
            feature = feature_names[col]
            color = colors[col % len(colors)]

            # Plot input
            ax.plot(t1, x[:, col], linestyle='--', linewidth=2, label="Input", color=color)
            # Plot true values
            ax.scatter(t3, y_true[:, col], label="True", color=color, marker='o', s=50, edgecolors='black', linewidth=0.5)
            # Plot predictions
            ax.scatter(t3, y_pred[:, col], label="Pred", color='black', marker='x', s=60)

            ax.set_title(f"{feature} | seed={seed} | MSE={mse:.4f}", fontsize=11)
            ax.grid(True)

            if row == num_samples - 1:
                ax.set_xlabel("Timestep")
            if col == 0:
                ax.set_ylabel("Value")
            if row == 0:
                ax.legend(loc='upper center', fontsize=8)

    plt.tight_layout()
    plt.show()

# %%
# Visualize
visualize_some_predictions(seq2seq_model, train_dataloader, device)
